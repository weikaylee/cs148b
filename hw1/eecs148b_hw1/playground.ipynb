# %%
import torchvision
model = torchvision.models.vit_b_16()
total_params = sum(param.numel() for param in model.parameters())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torchvision
#       2 model = torchvision.models.vit_b_16()
#       3 total_params = sum(param.numel() for param in model.parameters())
#
# File ~/miniconda3/lib/python3.13/site-packages/torchvision/__init__.py:5
#       2 import warnings
#       3 from modulefinder import Module
# ----> 5 import torch
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
#
# File ~/miniconda3/lib/python3.13/site-packages/torch/__init__.py:416
#     414     if USE_GLOBAL_DEPS:
#     415         _load_global_deps()
# --> 416     from torch._C import *  # noqa: F403
#     419 class SymInt:
#     420     """
# ...

# %%
!
# Out:
# pyenv: version `miniforge3-25.3.1-0' is not installed (set by /Users/kaywei/.pyenv/version)
# pyenv: pip: command not found
#
# The `pip' command exists in these Python versions:
#   3.14.2
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.
